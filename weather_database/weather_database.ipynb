# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pprint as pprint

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Import the requests library.
import requests

# Import the API key.
from config import OpenWeather_API_KEY

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + OpenWeather_API_KEY

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': 63.5833, 'lat': 53.1667},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 4.77,
#   'feels_like': -7.83,
#   'temp_min': 4.77,
#   'temp_max': 4.77,
#   'pressure': 1024,
#   'humidity': 93,
#   'sea_level': 1024,
#   'grnd_level': 1004},
#  'visibility': 10000,
#  'wind': {'speed': 12.48, 'deg': 37, 'gust': 23.51},
#  'clouds': {'all': 100},
#  'dt': 1647040114,
#  'sys': {'country': 'KZ', 'sunrise': 1647050897, 'sunset': 1647092575},
#  'timezone': 21600,
#  'id': 1519928,
#  'name': 'Kostanay',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sorland
# Processing Record 2 of Set 1 | nantucket
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | hukuntsi
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | yichun
# Processing Record 10 of Set 1 | shieli
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | cacu
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | kirkconnel
# Processing Record 17 of Set 1 | lorengau
# Processing Record 18 of Set 1 | wajima
# Processing Record 19 of Set 1 | nanortalik
# Processing Record 20 of Set 1 | karonga
# Processing Record 21 of Set 1 | perustica
# City not found. Skipping...
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | bandar
# Processing Record 24 of Set 1 | cockburn town
# Processing Record 25 of Set 1 | pisco
# Processing Record 26 of Set 1 | poum
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | camacha
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | faanui
# Processing Record 35 of Set 1 | shache
# Processing Record 36 of Set 1 | saint george
# Processing Record 37 of Set 1 | saint combs
# City not found. Skipping...
# Processing Record 38 of Set 1 | medea
# Processing Record 39 of Set 1 | aksu
# Processing Record 40 of Set 1 | puerto escondido
# Processing Record 41 of Set 1 | moose factory
# Processing Record 42 of Set 1 | ancud
# Processing Record 43 of Set 1 | sovetskiy
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | rincon
# Processing Record 47 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 1 | cururupu
# Processing Record 49 of Set 1 | adrar
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | jijiga
# Processing Record 3 of Set 2 | caravelas
# Processing Record 4 of Set 2 | bambous virieux
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | saldanha
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | kruisfontein
# Processing Record 9 of Set 2 | hirara
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | hofn
# Processing Record 12 of Set 2 | te anau
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | chernyshevskiy
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | ankara
# Processing Record 18 of Set 2 | comodoro rivadavia
# Processing Record 19 of Set 2 | baykit
# Processing Record 20 of Set 2 | guerrero negro
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | hengyang
# Processing Record 23 of Set 2 | esperance
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | takoradi
# Processing Record 26 of Set 2 | hessisch lichtenau
# Processing Record 27 of Set 2 | uarini
# Processing Record 28 of Set 2 | reyes
# Processing Record 29 of Set 2 | cairns
# Processing Record 30 of Set 2 | hinton
# Processing Record 31 of Set 2 | aksarka
# Processing Record 32 of Set 2 | parras
# City not found. Skipping...
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | hualmay
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | beringovskiy
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | ayr
# Processing Record 39 of Set 2 | lisakovsk
# Processing Record 40 of Set 2 | kerrobert
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | glasgow
# Processing Record 43 of Set 2 | isla vista
# Processing Record 44 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | high rock
# Processing Record 46 of Set 2 | praia da vitoria
# Processing Record 47 of Set 2 | valley city
# Processing Record 48 of Set 2 | puerto leguizamo
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | shakawe
# Processing Record 1 of Set 3 | san patricio
# Processing Record 2 of Set 3 | miraflores
# Processing Record 3 of Set 3 | vigrestad
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | tuatapere
# Processing Record 6 of Set 3 | san lawrenz
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | homer
# Processing Record 9 of Set 3 | saint-joseph
# Processing Record 10 of Set 3 | bredasdorp
# Processing Record 11 of Set 3 | cravo norte
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | albany
# Processing Record 14 of Set 3 | ostrovnoy
# Processing Record 15 of Set 3 | broken hill
# Processing Record 16 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 3 | mangrol
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | port hardy
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | henties bay
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | port lincoln
# Processing Record 25 of Set 3 | manggar
# Processing Record 26 of Set 3 | melo
# Processing Record 27 of Set 3 | kaitangata
# Processing Record 28 of Set 3 | ca mau
# Processing Record 29 of Set 3 | santa vitoria do palmar
# Processing Record 30 of Set 3 | nanakuli
# Processing Record 31 of Set 3 | motozintla
# Processing Record 32 of Set 3 | bolshiye uki
# City not found. Skipping...
# Processing Record 33 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 34 of Set 3 | lyngseidet
# Processing Record 35 of Set 3 | naliya
# Processing Record 36 of Set 3 | acapulco
# Processing Record 37 of Set 3 | vestmannaeyjar
# Processing Record 38 of Set 3 | tokonou
# Processing Record 39 of Set 3 | new norfolk
# Processing Record 40 of Set 3 | karpogory
# Processing Record 41 of Set 3 | east london
# Processing Record 42 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 43 of Set 3 | faya
# Processing Record 44 of Set 3 | matiguas
# Processing Record 45 of Set 3 | fort wayne
# Processing Record 46 of Set 3 | nikolskoye
# Processing Record 47 of Set 3 | provideniya
# Processing Record 48 of Set 3 | celestun
# Processing Record 49 of Set 3 | priekule
# Processing Record 50 of Set 3 | kavaratti
# Processing Record 1 of Set 4 | vila velha
# Processing Record 2 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 4 | kayerkan
# Processing Record 6 of Set 4 | richards bay
# Processing Record 7 of Set 4 | abu samrah
# Processing Record 8 of Set 4 | grindavik
# Processing Record 9 of Set 4 | saskylakh
# Processing Record 10 of Set 4 | mizdah
# Processing Record 11 of Set 4 | bengkulu
# Processing Record 12 of Set 4 | labuhan
# Processing Record 13 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 4 | ponta do sol
# Processing Record 15 of Set 4 | ribeira grande
# Processing Record 16 of Set 4 | yar-sale
# Processing Record 17 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 4 | chokwe
# Processing Record 19 of Set 4 | sorong
# Processing Record 20 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 21 of Set 4 | marsh harbour
# Processing Record 22 of Set 4 | lazaro cardenas
# Processing Record 23 of Set 4 | dingle
# Processing Record 24 of Set 4 | victoria
# Processing Record 25 of Set 4 | fairbanks
# Processing Record 26 of Set 4 | fez
# Processing Record 27 of Set 4 | alofi
# Processing Record 28 of Set 4 | outlook
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | clarksdale
# Processing Record 32 of Set 4 | riyadh
# Processing Record 33 of Set 4 | mount gambier
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | muros
# Processing Record 37 of Set 4 | kapenguria
# Processing Record 38 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 4 | havre-saint-pierre
# Processing Record 40 of Set 4 | olafsvik
# Processing Record 41 of Set 4 | solsvik
# City not found. Skipping...
# Processing Record 42 of Set 4 | tuktoyaktuk
# Processing Record 43 of Set 4 | san mariano
# Processing Record 44 of Set 4 | jalu
# Processing Record 45 of Set 4 | port macquarie
# Processing Record 46 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | palmer
# Processing Record 49 of Set 4 | miyako
# Processing Record 50 of Set 4 | vostok
# Processing Record 1 of Set 5 | diffa
# Processing Record 2 of Set 5 | port elizabeth
# Processing Record 3 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 5 | benghazi
# Processing Record 5 of Set 5 | luderitz
# Processing Record 6 of Set 5 | sao filipe
# Processing Record 7 of Set 5 | xingcheng
# Processing Record 8 of Set 5 | arica
# Processing Record 9 of Set 5 | constitucion
# Processing Record 10 of Set 5 | kandi
# Processing Record 11 of Set 5 | ahuimanu
# Processing Record 12 of Set 5 | korla
# Processing Record 13 of Set 5 | pandan
# Processing Record 14 of Set 5 | whitecourt
# Processing Record 15 of Set 5 | sal rei
# Processing Record 16 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 17 of Set 5 | tasiilaq
# Processing Record 18 of Set 5 | corinto
# Processing Record 19 of Set 5 | chipata
# Processing Record 20 of Set 5 | fort nelson
# Processing Record 21 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 5 | vestmanna
# Processing Record 23 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 5 | thinadhoo
# Processing Record 25 of Set 5 | the valley
# Processing Record 26 of Set 5 | kiunga
# Processing Record 27 of Set 5 | ambilobe
# Processing Record 28 of Set 5 | ushtobe
# Processing Record 29 of Set 5 | balkhash
# Processing Record 30 of Set 5 | markova
# Processing Record 31 of Set 5 | igarka
# Processing Record 32 of Set 5 | yumen
# Processing Record 33 of Set 5 | severo-kurilsk
# Processing Record 34 of Set 5 | kodiak
# Processing Record 35 of Set 5 | maniitsoq
# Processing Record 36 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 5 | antalaha
# Processing Record 38 of Set 5 | shingu
# Processing Record 39 of Set 5 | pozo colorado
# Processing Record 40 of Set 5 | abu dhabi
# Processing Record 41 of Set 5 | hamilton
# Processing Record 42 of Set 5 | port augusta
# Processing Record 43 of Set 5 | queanbeyan
# Processing Record 44 of Set 5 | maiduguri
# Processing Record 45 of Set 5 | brae
# Processing Record 46 of Set 5 | gravenhurst
# Processing Record 47 of Set 5 | aracaju
# Processing Record 48 of Set 5 | yakeshi
# Processing Record 49 of Set 5 | carnarvon
# Processing Record 50 of Set 5 | half moon bay
# Processing Record 1 of Set 6 | chuy
# Processing Record 2 of Set 6 | lerwick
# Processing Record 3 of Set 6 | olbia
# Processing Record 4 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 5 of Set 6 | naze
# Processing Record 6 of Set 6 | atambua
# Processing Record 7 of Set 6 | esterhazy
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 6 | babu
# Processing Record 11 of Set 6 | cabo san lucas
# Processing Record 12 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 6 | bhag
# Processing Record 14 of Set 6 | lata
# Processing Record 15 of Set 6 | magalia
# Processing Record 16 of Set 6 | buala
# Processing Record 17 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 6 | broome
# Processing Record 19 of Set 6 | belmonte
# Processing Record 20 of Set 6 | morgan city
# Processing Record 21 of Set 6 | popondetta
# Processing Record 22 of Set 6 | parsons
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | trincomalee
# Processing Record 25 of Set 6 | pendleton
# Processing Record 26 of Set 6 | pacifica
# Processing Record 27 of Set 6 | salinopolis
# Processing Record 28 of Set 6 | pala
# Processing Record 29 of Set 6 | khatanga
# Processing Record 30 of Set 6 | fortuna
# Processing Record 31 of Set 6 | kurumkan
# Processing Record 32 of Set 6 | gizo
# Processing Record 33 of Set 6 | namatanai
# Processing Record 34 of Set 6 | kenai
# Processing Record 35 of Set 6 | skjervoy
# Processing Record 36 of Set 6 | ixtapa
# Processing Record 37 of Set 6 | barentu
# Processing Record 38 of Set 6 | kholodnyy
# Processing Record 39 of Set 6 | warmbad
# Processing Record 40 of Set 6 | magaramkent
# Processing Record 41 of Set 6 | tieling
# Processing Record 42 of Set 6 | concepcion del oro
# Processing Record 43 of Set 6 | terrace
# Processing Record 44 of Set 6 | rozkishne
# Processing Record 45 of Set 6 | pundaguitan
# Processing Record 46 of Set 6 | lasa
# Processing Record 47 of Set 6 | mersing
# Processing Record 48 of Set 6 | guarapari
# Processing Record 49 of Set 6 | itoman
# Processing Record 50 of Set 6 | kupang
# Processing Record 1 of Set 7 | longwy
# Processing Record 2 of Set 7 | cidreira
# Processing Record 3 of Set 7 | gat
# Processing Record 4 of Set 7 | mahebourg
# Processing Record 5 of Set 7 | bandarbeyla
# Processing Record 6 of Set 7 | port hedland
# Processing Record 7 of Set 7 | kaabong
# Processing Record 8 of Set 7 | neiafu
# Processing Record 9 of Set 7 | eureka
# Processing Record 10 of Set 7 | kitgum
# Processing Record 11 of Set 7 | mecca
# Processing Record 12 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 13 of Set 7 | carballo
# Processing Record 14 of Set 7 | hambantota
# Processing Record 15 of Set 7 | wagar
# Processing Record 16 of Set 7 | aklavik
# Processing Record 17 of Set 7 | amot
# Processing Record 18 of Set 7 | erzin
# Processing Record 19 of Set 7 | oktyabrskoye
# Processing Record 20 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 21 of Set 7 | dhangadhi
# Processing Record 22 of Set 7 | paamiut
# Processing Record 23 of Set 7 | anadyr
# Processing Record 24 of Set 7 | waingapu
# Processing Record 25 of Set 7 | kholmogory
# Processing Record 26 of Set 7 | hobyo
# Processing Record 27 of Set 7 | port shepstone
# Processing Record 28 of Set 7 | alzey
# Processing Record 29 of Set 7 | sourpi
# Processing Record 30 of Set 7 | morrope
# Processing Record 31 of Set 7 | bathsheba
# Processing Record 32 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 7 | los llanos de aridane
# Processing Record 34 of Set 7 | beyneu
# Processing Record 35 of Set 7 | liling
# Processing Record 36 of Set 7 | sandnessjoen
# Processing Record 37 of Set 7 | altamont
# Processing Record 38 of Set 7 | natal
# Processing Record 39 of Set 7 | yulara
# Processing Record 40 of Set 7 | lagunas
# Processing Record 41 of Set 7 | lompoc
# Processing Record 42 of Set 7 | oga
# Processing Record 43 of Set 7 | klaksvik
# Processing Record 44 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 7 | san juan de los lagos
# Processing Record 46 of Set 7 | kangaatsiaq
# Processing Record 47 of Set 7 | sambava
# Processing Record 48 of Set 7 | tiksi
# Processing Record 49 of Set 7 | joshimath
# Processing Record 50 of Set 7 | alanya
# Processing Record 1 of Set 8 | quatre cocos
# Processing Record 2 of Set 8 | tazovskiy
# Processing Record 3 of Set 8 | neuquen
# Processing Record 4 of Set 8 | roald
# Processing Record 5 of Set 8 | borogontsy
# Processing Record 6 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 8 | saint-denis
# Processing Record 8 of Set 8 | santa cruz
# Processing Record 9 of Set 8 | kisangani
# Processing Record 10 of Set 8 | tonj
# Processing Record 11 of Set 8 | georgetown
# Processing Record 12 of Set 8 | vieste
# Processing Record 13 of Set 8 | dezful
# Processing Record 14 of Set 8 | matara
# Processing Record 15 of Set 8 | bontang
# Processing Record 16 of Set 8 | kita
# Processing Record 17 of Set 8 | coquimbo
# Processing Record 18 of Set 8 | le port
# Processing Record 19 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 8 | douentza
# Processing Record 21 of Set 8 | namikupa
# Processing Record 22 of Set 8 | clyde river
# Processing Record 23 of Set 8 | geraldton
# Processing Record 24 of Set 8 | dubti
# Processing Record 25 of Set 8 | goderich
# Processing Record 26 of Set 8 | bilibino
# Processing Record 27 of Set 8 | tortoli
# Processing Record 28 of Set 8 | pingliang
# Processing Record 29 of Set 8 | hashtgerd
# Processing Record 30 of Set 8 | touros
# Processing Record 31 of Set 8 | nelson bay
# Processing Record 32 of Set 8 | mehriz
# Processing Record 33 of Set 8 | kendari
# Processing Record 34 of Set 8 | vardo
# Processing Record 35 of Set 8 | mangai
# Processing Record 36 of Set 8 | yilan
# Processing Record 37 of Set 8 | san cristobal
# Processing Record 38 of Set 8 | ayagoz
# Processing Record 39 of Set 8 | kununurra
# Processing Record 40 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 8 | soyo
# Processing Record 42 of Set 8 | hammerfest
# Processing Record 43 of Set 8 | igrim
# Processing Record 44 of Set 8 | carbonia
# Processing Record 45 of Set 8 | darnah
# Processing Record 46 of Set 8 | padilla
# Processing Record 47 of Set 8 | puerto madryn
# Processing Record 48 of Set 8 | dubbo
# Processing Record 49 of Set 8 | pelotas
# Processing Record 50 of Set 8 | karratha
# Processing Record 1 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 9 | jaru
# Processing Record 3 of Set 9 | sao felix do xingu
# Processing Record 4 of Set 9 | zhigansk
# Processing Record 5 of Set 9 | seremban
# Processing Record 6 of Set 9 | san matias
# Processing Record 7 of Set 9 | turayf
# Processing Record 8 of Set 9 | gouyave
# Processing Record 9 of Set 9 | nauta
# Processing Record 10 of Set 9 | phalaborwa
# Processing Record 11 of Set 9 | orlovskiy
# Processing Record 12 of Set 9 | frontera
# Processing Record 13 of Set 9 | menongue
# Processing Record 14 of Set 9 | baleshwar
# Processing Record 15 of Set 9 | dwarka
# Processing Record 16 of Set 9 | havelock
# Processing Record 17 of Set 9 | cobija
# Processing Record 18 of Set 9 | atar
# Processing Record 19 of Set 9 | novobureyskiy
# Processing Record 20 of Set 9 | san policarpo
# Processing Record 21 of Set 9 | valenca
# Processing Record 22 of Set 9 | kyzyl-suu
# Processing Record 23 of Set 9 | inhambane
# Processing Record 24 of Set 9 | westport
# Processing Record 25 of Set 9 | zomin
# Processing Record 26 of Set 9 | smirnykh
# Processing Record 27 of Set 9 | praia
# Processing Record 28 of Set 9 | amatlan
# City not found. Skipping...
# Processing Record 29 of Set 9 | zhangjiakou
# Processing Record 30 of Set 9 | morro bay
# Processing Record 31 of Set 9 | ha giang
# Processing Record 32 of Set 9 | sibolga
# Processing Record 33 of Set 9 | tromso
# Processing Record 34 of Set 9 | sawang daen din
# Processing Record 35 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 9 | miranda do corvo
# Processing Record 37 of Set 9 | qurbah
# City not found. Skipping...
# Processing Record 38 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 9 | krasnorechenskiy
# Processing Record 40 of Set 9 | saint-pierre
# Processing Record 41 of Set 9 | koekelare
# Processing Record 42 of Set 9 | peachland
# Processing Record 43 of Set 9 | yinchuan
# Processing Record 44 of Set 9 | semey
# Processing Record 45 of Set 9 | berlevag
# Processing Record 46 of Set 9 | kieta
# Processing Record 47 of Set 9 | san carlos de bariloche
# Processing Record 48 of Set 9 | rorvik
# Processing Record 49 of Set 9 | el badari
# City not found. Skipping...
# Processing Record 50 of Set 9 | urucui
# Processing Record 1 of Set 10 | khandyga
# Processing Record 2 of Set 10 | zyryanka
# Processing Record 3 of Set 10 | lianran
# Processing Record 4 of Set 10 | dengzhou
# Processing Record 5 of Set 10 | chimala
# Processing Record 6 of Set 10 | inirida
# Processing Record 7 of Set 10 | ridgecrest
# Processing Record 8 of Set 10 | mareeba
# Processing Record 9 of Set 10 | sao joao da barra
# Processing Record 10 of Set 10 | pichataro
# Processing Record 11 of Set 10 | stara synyava
# Processing Record 12 of Set 10 | khandbari
# Processing Record 13 of Set 10 | kissidougou
# Processing Record 14 of Set 10 | marzuq
# Processing Record 15 of Set 10 | milove
# Processing Record 16 of Set 10 | bytow
# Processing Record 17 of Set 10 | ust-maya
# Processing Record 18 of Set 10 | san rafael del sur
# Processing Record 19 of Set 10 | gornozavodsk
# Processing Record 20 of Set 10 | tessalit
# Processing Record 21 of Set 10 | kaduqli
# Processing Record 22 of Set 10 | salalah
# Processing Record 23 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 10 | wonthaggi
# Processing Record 25 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 26 of Set 10 | tautira
# Processing Record 27 of Set 10 | mubi
# Processing Record 28 of Set 10 | tucurui
# Processing Record 29 of Set 10 | sakakah
# Processing Record 30 of Set 10 | lubao
# Processing Record 31 of Set 10 | tarko-sale
# Processing Record 32 of Set 10 | hoa binh
# Processing Record 33 of Set 10 | svetlaya
# Processing Record 34 of Set 10 | batemans bay
# Processing Record 35 of Set 10 | brigantine
# Processing Record 36 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 10 | esmeraldas
# Processing Record 38 of Set 10 | isangel
# Processing Record 39 of Set 10 | presidencia roque saenz pena
# Processing Record 40 of Set 10 | chapais
# Processing Record 41 of Set 10 | pangkalanbuun
# Processing Record 42 of Set 10 | saint-paul
# Processing Record 43 of Set 10 | lavrentiya
# Processing Record 44 of Set 10 | grakhovo
# Processing Record 45 of Set 10 | kalmunai
# Processing Record 46 of Set 10 | sinnamary
# Processing Record 47 of Set 10 | asau
# Processing Record 48 of Set 10 | gamba
# Processing Record 49 of Set 10 | taltal
# Processing Record 50 of Set 10 | olinda
# Processing Record 1 of Set 11 | kropotkin
# Processing Record 2 of Set 11 | peniche
# Processing Record 3 of Set 11 | laguna
# Processing Record 4 of Set 11 | iquitos
# Processing Record 5 of Set 11 | beausejour
# Processing Record 6 of Set 11 | kollam
# Processing Record 7 of Set 11 | roma
# Processing Record 8 of Set 11 | lagoa
# Processing Record 9 of Set 11 | ilulissat
# Processing Record 10 of Set 11 | mulege
# Processing Record 11 of Set 11 | padang
# Processing Record 12 of Set 11 | mandiana
# Processing Record 13 of Set 11 | duki
# Processing Record 14 of Set 11 | kabo
# Processing Record 15 of Set 11 | narsaq
# Processing Record 16 of Set 11 | ciudad bolivar
# Processing Record 17 of Set 11 | fallon
# Processing Record 18 of Set 11 | fayaoue
# Processing Record 19 of Set 11 | sausar
# Processing Record 20 of Set 11 | tulun
# Processing Record 21 of Set 11 | avera
# Processing Record 22 of Set 11 | kamaishi
# Processing Record 23 of Set 11 | gigmoto
# Processing Record 24 of Set 11 | konigs wusterhausen
# Processing Record 25 of Set 11 | sarangani
# Processing Record 26 of Set 11 | aksum
# Processing Record 27 of Set 11 | okhotsk
# Processing Record 28 of Set 11 | preobrazheniye
# Processing Record 29 of Set 11 | veraval
# Processing Record 30 of Set 11 | bourail
# Processing Record 31 of Set 11 | mitu
# Processing Record 32 of Set 11 | challapata
# Processing Record 33 of Set 11 | rio gallegos
# Processing Record 34 of Set 11 | yenagoa
# Processing Record 35 of Set 11 | nekrasovka
# Processing Record 36 of Set 11 | lewistown
# Processing Record 37 of Set 11 | coos bay
# Processing Record 38 of Set 11 | khakhea
# Processing Record 39 of Set 11 | cesme
# Processing Record 40 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 41 of Set 11 | bela
# Processing Record 42 of Set 11 | muriti
# Processing Record 43 of Set 11 | hayden
# Processing Record 44 of Set 11 | chabahar
# Processing Record 45 of Set 11 | xai-xai
# Processing Record 46 of Set 11 | palauig
# Processing Record 47 of Set 11 | dargaville
# Processing Record 48 of Set 11 | ajdabiya
# Processing Record 49 of Set 11 | sopot
# Processing Record 50 of Set 11 | wladyslawowo
# Processing Record 1 of Set 12 | alyangula
# Processing Record 2 of Set 12 | hokitika
# Processing Record 3 of Set 12 | tigil
# Processing Record 4 of Set 12 | rio arriba
# Processing Record 5 of Set 12 | soure
# Processing Record 6 of Set 12 | bilma
# Processing Record 7 of Set 12 | lexington park
# Processing Record 8 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 9 of Set 12 | tunceli
# Processing Record 10 of Set 12 | batagay-alyta
# Processing Record 11 of Set 12 | tomatlan
# Processing Record 12 of Set 12 | nizhnevartovsk
# Processing Record 13 of Set 12 | rio branco do sul
# Processing Record 14 of Set 12 | bollnas
# Processing Record 15 of Set 12 | melfi
# Processing Record 16 of Set 12 | huaicheng
# Processing Record 17 of Set 12 | leningradskiy
# Processing Record 18 of Set 12 | maarianhamina
# Processing Record 19 of Set 12 | killybegs
# Processing Record 20 of Set 12 | iqaluit
# Processing Record 21 of Set 12 | gurdaha
# Processing Record 22 of Set 12 | comala
# Processing Record 23 of Set 12 | dejen
# Processing Record 24 of Set 12 | las vegas
# Processing Record 25 of Set 12 | campo maior
# Processing Record 26 of Set 12 | san joaquin
# Processing Record 27 of Set 12 | van buren
# Processing Record 28 of Set 12 | payo
# Processing Record 29 of Set 12 | mbanza-ngungu
# Processing Record 30 of Set 12 | zhanaozen
# Processing Record 31 of Set 12 | karasburg
# Processing Record 32 of Set 12 | buraydah
# Processing Record 33 of Set 12 | boone
# Processing Record 34 of Set 12 | bennettsville
# Processing Record 35 of Set 12 | veere
# Processing Record 36 of Set 12 | cruz alta
# Processing Record 37 of Set 12 | matamoros
# Processing Record 38 of Set 12 | nome
# Processing Record 39 of Set 12 | tuy hoa
# Processing Record 40 of Set 12 | haines junction
# Processing Record 41 of Set 12 | songea
# Processing Record 42 of Set 12 | shimoda
# Processing Record 43 of Set 12 | havoysund
# Processing Record 44 of Set 12 | kirakira
# Processing Record 45 of Set 12 | hudson bay
# Processing Record 46 of Set 12 | san ramon
# Processing Record 47 of Set 12 | dakar
# Processing Record 48 of Set 12 | dobson
# Processing Record 49 of Set 12 | kloulklubed
# Processing Record 50 of Set 12 | yashkul
# Processing Record 1 of Set 13 | bastrop
# Processing Record 2 of Set 13 | boa esperanca
# Processing Record 3 of Set 13 | kez
# Processing Record 4 of Set 13 | puerto maldonado
# Processing Record 5 of Set 13 | nador
# Processing Record 6 of Set 13 | concepcion
# Processing Record 7 of Set 13 | conakry
# Processing Record 8 of Set 13 | oranjestad
# Processing Record 9 of Set 13 | husavik
# Processing Record 10 of Set 13 | alta floresta
# Processing Record 11 of Set 13 | miles city
# Processing Record 12 of Set 13 | novyy urengoy
# Processing Record 13 of Set 13 | plouzane
# Processing Record 14 of Set 13 | straumen
# Processing Record 15 of Set 13 | tripoli
# Processing Record 16 of Set 13 | kansk
# Processing Record 17 of Set 13 | saint-georges
# Processing Record 18 of Set 13 | kargasok
# Processing Record 19 of Set 13 | kusa
# Processing Record 20 of Set 13 | moron
# Processing Record 21 of Set 13 | economy
# Processing Record 22 of Set 13 | baniyas
# Processing Record 23 of Set 13 | college
# Processing Record 24 of Set 13 | polyarnyy
# Processing Record 25 of Set 13 | kourou
# Processing Record 26 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 13 | san luis
# Processing Record 28 of Set 13 | launceston
# Processing Record 29 of Set 13 | pacific grove
# Processing Record 30 of Set 13 | san vicente
# Processing Record 31 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 13 | meulaboh
# Processing Record 33 of Set 13 | pochinki
# Processing Record 34 of Set 13 | wahpeton
# Processing Record 35 of Set 13 | najran
# Processing Record 36 of Set 13 | xaghra
# Processing Record 37 of Set 13 | road town
# Processing Record 38 of Set 13 | port pirie
# Processing Record 39 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 13 | puntilla aldama
# Processing Record 42 of Set 13 | coxim
# Processing Record 43 of Set 13 | santa rosa
# Processing Record 44 of Set 13 | sioux lookout
# Processing Record 45 of Set 13 | esna
# Processing Record 46 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 13 | novyy urgal
# Processing Record 48 of Set 13 | sonipat
# Processing Record 49 of Set 13 | saint anthony
# Processing Record 50 of Set 13 | qingyuan
# Processing Record 1 of Set 14 | kutum
# Processing Record 2 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 14 | banda aceh
# Processing Record 4 of Set 14 | pinos puente
# Processing Record 5 of Set 14 | huntley
# Processing Record 6 of Set 14 | strelca
# City not found. Skipping...
# Processing Record 7 of Set 14 | flinders
# Processing Record 8 of Set 14 | karema
# Processing Record 9 of Set 14 | sembe
# Processing Record 10 of Set 14 | ahipara
# Processing Record 11 of Set 14 | harrisonville
# Processing Record 12 of Set 14 | aykhal
# Processing Record 13 of Set 14 | arman
# Processing Record 14 of Set 14 | birganj
# Processing Record 15 of Set 14 | rosignol
# Processing Record 16 of Set 14 | egvekinot
# Processing Record 17 of Set 14 | wanning
# Processing Record 18 of Set 14 | auki
# Processing Record 19 of Set 14 | samdari
# Processing Record 20 of Set 14 | port hueneme
# Processing Record 21 of Set 14 | bonavista
# Processing Record 22 of Set 14 | alamogordo
# Processing Record 23 of Set 14 | point pleasant
# Processing Record 24 of Set 14 | lovington
# Processing Record 25 of Set 14 | pangnirtung
# Processing Record 26 of Set 14 | riberalta
# Processing Record 27 of Set 14 | verkh-usugli
# Processing Record 28 of Set 14 | mantua
# Processing Record 29 of Set 14 | nathdwara
# Processing Record 30 of Set 14 | bubaque
# Processing Record 31 of Set 14 | portland
# Processing Record 32 of Set 14 | kabansk
# Processing Record 33 of Set 14 | kortkeros
# Processing Record 34 of Set 14 | aswan
# Processing Record 35 of Set 14 | sigli
# Processing Record 36 of Set 14 | tashla
# Processing Record 37 of Set 14 | angoche
# Processing Record 38 of Set 14 | san quintin
# Processing Record 39 of Set 14 | kerman
# Processing Record 40 of Set 14 | pokhara
# Processing Record 41 of Set 14 | atasu
# Processing Record 42 of Set 14 | krasnoye-na-volge
# Processing Record 43 of Set 14 | brokopondo
# Processing Record 44 of Set 14 | seinajoki
# Processing Record 45 of Set 14 | bria
# Processing Record 46 of Set 14 | trairi
# Processing Record 47 of Set 14 | jibuti
# Processing Record 48 of Set 14 | lang son
# Processing Record 49 of Set 14 | dongsheng
# Processing Record 50 of Set 14 | coahuayana
# Processing Record 1 of Set 15 | vera cruz
# Processing Record 2 of Set 15 | sendafa
# Processing Record 3 of Set 15 | cherskiy
# Processing Record 4 of Set 15 | bonaventure
# Processing Record 5 of Set 15 | kapuskasing
# Processing Record 6 of Set 15 | bachaquero
# Processing Record 7 of Set 15 | bom jesus
# Processing Record 8 of Set 15 | fort dodge
# Processing Record 9 of Set 15 | sabang
# Processing Record 10 of Set 15 | zhoucheng
# Processing Record 11 of Set 15 | banyo
# Processing Record 12 of Set 15 | dayong
# Processing Record 13 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 14 of Set 15 | berdigestyakh
# Processing Record 15 of Set 15 | vagamo
# Processing Record 16 of Set 15 | margate
# Processing Record 17 of Set 15 | samarai
# Processing Record 18 of Set 15 | metro
# Processing Record 19 of Set 15 | puteyets
# Processing Record 20 of Set 15 | giddalur
# Processing Record 21 of Set 15 | leninskoye
# Processing Record 22 of Set 15 | zlobin
# Processing Record 23 of Set 15 | frunze
# Processing Record 24 of Set 15 | kudahuvadhoo
# Processing Record 25 of Set 15 | plerin
# Processing Record 26 of Set 15 | agaro
# Processing Record 27 of Set 15 | nabire
# Processing Record 28 of Set 15 | msowero
# Processing Record 29 of Set 15 | aflao
# Processing Record 30 of Set 15 | taksimo
# Processing Record 31 of Set 15 | synya
# Processing Record 32 of Set 15 | bonthe
# Processing Record 33 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 15 | quelimane
# Processing Record 35 of Set 15 | plettenberg bay
# Processing Record 36 of Set 15 | pital
# Processing Record 37 of Set 15 | san andres
# Processing Record 38 of Set 15 | kristiansund
# Processing Record 39 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 15 | kinkala
# Processing Record 41 of Set 15 | pierre
# Processing Record 42 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 43 of Set 15 | lazarev
# Processing Record 44 of Set 15 | zaykovo
# Processing Record 45 of Set 15 | dudinka
# Processing Record 46 of Set 15 | waipawa
# Processing Record 47 of Set 15 | mikkeli
# Processing Record 48 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 50 of Set 15 | port-gentil
# Processing Record 1 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 16 | laredo
# Processing Record 3 of Set 16 | lufkin
# Processing Record 4 of Set 16 | qeshm
# Processing Record 5 of Set 16 | cortez
# Processing Record 6 of Set 16 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 7 of Set 16 | wanaka
# Processing Record 8 of Set 16 | lakatoro
# Processing Record 9 of Set 16 | cap malheureux
# Processing Record 10 of Set 16 | taoudenni
# Processing Record 11 of Set 16 | ternate
# Processing Record 12 of Set 16 | isabela
# Processing Record 13 of Set 16 | conde
# Processing Record 14 of Set 16 | komsomolskiy
# Processing Record 15 of Set 16 | tambo
# Processing Record 16 of Set 16 | abha
# Processing Record 17 of Set 16 | parabel
# Processing Record 18 of Set 16 | staryy nadym
# Processing Record 19 of Set 16 | ferme-neuve
# Processing Record 20 of Set 16 | piacabucu
# Processing Record 21 of Set 16 | honiara
# Processing Record 22 of Set 16 | mazarron
# Processing Record 23 of Set 16 | mahanoro
# Processing Record 24 of Set 16 | qostanay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Sorland  67.6670   12.6934     42.46        84          95       10.98
# 1  Nantucket  41.2835  -70.0995     41.11        87           0        6.91
# 2      Vaini -21.2000 -175.2000     84.36        84          75        8.05
# 3  Upernavik  72.7868  -56.1549    -16.49       100          71        7.81
# 4   Hukuntsi -24.0000   21.7500     74.19        44          26       11.81
# 5     Hobart -42.8794  147.3294     66.25        62          20        8.05
# 6      Kapaa  22.0752 -159.3190     81.12        70          20       10.36
# 7    Ushuaia -54.8000  -68.3000     47.86        57          20       17.27
# 8     Yichun  47.7000  128.9000     13.32        92          73        0.40
# 9     Shieli  44.1667   66.7500     50.61        75          97        7.20
#
#   Country                 Date Current Description
# 0      NO  2022-03-11 23:08:36     overcast clouds
# 1      US  2022-03-11 23:03:44           clear sky
# 2      TO  2022-03-11 23:08:37       broken clouds
# 3      GL  2022-03-11 23:08:37       broken clouds
# 4      BW  2022-03-11 23:08:38    scattered clouds
# 5      AU  2022-03-11 23:08:38          few clouds
# 6      US  2022-03-11 23:08:39          few clouds
# 7      AR  2022-03-11 23:07:35          few clouds
# 8      CN  2022-03-11 23:08:39       broken clouds
# 9      KZ  2022-03-11 23:08:39     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
